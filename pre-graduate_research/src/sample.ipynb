# %% [markdown]
# # プレ卒研用のサンプルコード

# %% [markdown]
# ## 初期設定
#
# #### 使用するプログラミング言語
#
# 「ランタイム」=> 「ランタイムのタイプを変更」=>「ランタイムのタイプ」=> Python 3
#
# #### GPUを使用する場合
#
# 「ランタイム」=> 「ランタイムのタイプを変更」=>「ハードウェアアクセラレータ」=> GPU

# %% [markdown]
# ## Google Driveをマウント
#
# プログラムの実行結果ファイルをGoogle Driveに保存したい時がある．
#
# そのような時は，以下のコマンドを実行すれば良い．

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# ==================================================
# GoogleDriveのColab Notebooksディレクトリ内にsample.txtを生成
# ==================================================
file_path = '/content/gdrive/My Drive/Colab Notebooks/sample.txt'
with open(file_path, 'w') as file:
  file.write("Below indicates result\n")

# %% [markdown]
# ## サンプルコード

# %%
import numpy as np

x = 1
y = 2
sum = x + y

print('{} + {} = {}'.format(x, y, sum))
# Out:
# 1 + 2 = 3
